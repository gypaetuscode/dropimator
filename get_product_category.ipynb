# %%
import pandas as pd
import numpy as np
from ast import literal_eval

from sklearn.metrics import classification_report

datafile_path = 'product_embeddings.csv'

df = pd.read_csv(datafile_path)
df["embedding"] = df['embedding'].apply(literal_eval).apply(np.array)

df
# Out:
#     Unnamed: 0 manufacturer_name  \
# 0            0     1Up Nutrition
# 1            1     1Up Nutrition
# 2            2     1Up Nutrition
# 3            3     1Up Nutrition
# 4            4     1Up Nutrition
# ..         ...               ...
# 95          95      5% Nutrition
# 96          96      5% Nutrition
# 97          97      5% Nutrition
# 98          98      5% Nutrition
# 99          99      5% Nutrition
#
#                                                  name  \
# 0     Vegan Greens & Reds Superfoods, Lemonade - 300g
# 1   Organic Vegan Greens & Reds Superfoods, Pineap...
# 2                      Pure Rebuild, Pineapple - 600g
# 3        Vegan Greens & Reds Superfoods, Peach - 300g
# 4                       Vegan Protein, Vanilla - 900g
# ..                                                ...
# 95  AllDayYouMay Caffeinated - Legendary Series, S...
# 96  Crea-TEN - Legendary Series, Blueberry Lemonad...
# 97  AllDayYouMay - Legendary Series, Lemon Lime - ...
# ...

# %%
from openai.embeddings_utils import cosine_similarity, get_embedding
from sklearn.metrics import PrecisionRecallDisplay

def evaluate_embeddings_approach(product_embeddings, labels, embedding_model):
    label_embeddings = [get_embedding(label, engine=embedding_model) for label in labels]

    def label_score(product_embeddings, label_embeddings):
        assigned_labels = []
        for product in product_embeddings:
            scores = [cosine_similarity(product, label) for label in label_embeddings]
            assigned_labels.append(labels[scores.index(max(scores))])
        return assigned_labels

    assigned_labels = label_score(product_embeddings, label_embeddings)
    return assigned_labels
    
product_embeddings = df['embedding']    
labels = [
    'Proteine',
    'Aminoacizi',
    'Vitamine si Minerale',
    'Batoane si Gustari Fitness',
    'Suplimente pentru slabit',
    'Performanta/Stimulatoare',
    'Pre-Workout',
    'Creatina',
    'Imbracaminte si acesorii pentru sala',
    'Masa musculara'
]
embedding_model = "text-embedding-ada-002"

print(evaluate_embeddings_approach(product_embeddings, labels, embedding_model));
# Out:
# ['Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Proteine', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Suplimente pentru slabit', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Pre-Workout', 'Creatina', 'Creatina', 'Creatina', 'Pre-Workout', 'Creatina', 'Pre-Workout', 'Creatina', 'Creatina', 'Pre-Workout', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Pre-Workout', 'Creatina', 'Batoane si Gustari Fitness', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Creatina', 'Pre-Workout', 'Creatina
# ...
